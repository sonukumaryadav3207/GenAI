# %% [markdown]
# # Modules and packages

# %%
def addition(num1,num2):
    return num1+num2

# %%
addition(4,5)
# Out:
# 9

# %% [markdown]
# ### i want to use this logic of the function in this file into other files

# %%
import math

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
## how complex the logic of a square root function is going to be

# %% [markdown]
# ## Module
#
# A module in python is simply afile containing a python code f(function,classes, or variables)  that can be imported and used in other programs

# %% [markdown]
# ### numpy  ---> numpy module is going to help us outt with applyiong scientific calculation on the array and we can store our data by consuming less space and we can apply the opeartion with out arraya bit more faster as comapared to those of the list

# %%
from math import *
print(cos(90))
print(pi)
print(factorial(5))
# Out:
# -0.4480736161291701
# 3.141592653589793
# 120

# %%
import numpy

# %%
list_item =[[1,2,3,4,5]]
numpy_array=numpy.array(list_item)
type(numpy_array)
print(numpy_array)
# Out:
# [[1 2 3 4 5]]
