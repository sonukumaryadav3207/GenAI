# %% [markdown]
# # Streamlit

# %% [markdown]
# ## Streamlit is an Open source Python Library used to build beutiful , interactive web applicationfor data science and machine learning with minimal effort .

# %% [markdown]
# ### Why to use Streamlit
#
# ### Easy to use
# ### Fast Development
# ###  Intractivr UI elements  ---> Buttons , Sliders , Text inputs,charts
