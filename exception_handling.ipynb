# %% [markdown]
# # Exception Handling

# %%
num = int(input("enter the denominator for division"))
result =  1/num
print(result)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 num = int(input("enter the denominator for division"))
# ----> 2 result =  1/num
#       3 print(result)
#
# ZeroDivisionError: division by zero

# %%
## error --> exception handling

num = int(input("enter the denominator for division"))
if(num == 0):
    print("i asked you to not to provide denominatopr as 0 but you still provided hnecne no result for you ")
else:
    result =  1/num
    print(result)
# Out:
# i asked you to not to provide denominatopr as 0 but you still provided hnecne no result for you

# %% [markdown]
# #### Different type of Eception
#
# ## ZeroDivision Error --> Dividing by zero
# ## FileNotfoundError --> File not found
# ## ValueError --> Invalid value
# ## TypeError - > invalid type

# %%
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
b=25
a=b

# %% [markdown]
# ## Exception Handling
#
# ## try  except block

# %%
try:
    a=b
except:
    print("b is not define")

# %%
try :
    a=b
except NameError as exception:
    print(exception)

# %%
den = int(input("Enter the denominator"))
try :
    result = 1/den
    print(result)
except ZeroDivisionError as ex:
    print(ex)
# Out:
# division by zero

# %%
try :
    result = a/b
    print(result)
    a=c
    div=5/'s'
# except ZeroDivisionError as ex:
#     print(ex)

# except NameError as ex2:
#     print(ex2)

except Exception as ex3:
    print(ex3)
# Out:
# 1.0
# name 'c' is not defined

# %% [markdown]
# ## if we are getting an error and we are not aware of that hich specific error it is then we can use the primary exception class which is Exception
