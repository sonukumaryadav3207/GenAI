# %%
jhon_ht = int(input("enter th height"))
jack_ht = int(input("enter th height"))
danial_ht = int(input("enter th height"))

if jhon_ht > jack_ht>danial_ht:
    print("jhone is taller than among three ")
elif jack_ht>jhon_ht>danial_ht:
    print("jack is taller among three")
else:
    print("danial is taller than among three")
# Out:
# danial is taller than among three

# %%
year = int(input("Enter the year value :"))
if year%4==0:
    if year%100==0:
        if year%400 ==0:
            print("Year is a leap year")
        else:
            print("Not a leap year")
    else:
        print("year is a leap year")
else:
    print("year is not a leap year")
# Out:
# Year is a leap year
