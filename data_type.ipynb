# %% [markdown]
# # Data Types

# %% [markdown]
# ## Data types are classification of the data that tells the compiler or the interpreter that what kind of values we can store into a variable and how much amount of memory will be consumed to store the data and the the operation it can peform.

# %%
age= int(input("Enter you Age: "))

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
print(age)
# Out:
# 23

# %%
age2=40

# %%
print(age2)
# Out:
# 40

# %%
print(age + age2)
# Out:
# 63
