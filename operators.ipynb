# %% [markdown]
# # Operators

# %%
a=5
b=6
print(a+b)

# %% [markdown]
# ## operators  help in applying operation on the given operands

# %% [markdown]
# ## typpes of operators :
# 1. Airthmetic Operators
# Addition (+)
# Substraction (-)
# Product or Multiplication (*)
# Division(/)
# Modulus(%)
# Floor(//)
# Exponent(a**b)
#
# 2. Comparison Operators
#
# Greater Than (>)
# Less than (<)
# >=
# <=
# ==
# !=
#
# 3. Logical Operators
#
# and
# or
# not

# %%
# Addition Operator
a=5
b=6
print(a+b)
# Out:
# 11

# %%
# floor operator
a=18
b=5
print(a//b)
# Out:
# 3.6

# %%
# modulo operator gives the remainder of the division
a=18 
b=7
print(a%b)
# Out:
# 4

# %%
# calculator

a= int(input("Enter the first value :"))
b= int(input("Enter the Second value :"))

operation = input("Enter the operation out of +,-,*,/ :")

if(operation == "+"):
    print("The addition of two numbers is : ",a+b)

if(operation == "-"):
    print("The subtraction of two numbers is : ",a-b)

if(operation == "*"):
    print("The multiplication of two numbers is : ",a*b)

if(operation == "/"):
    print("The division of two numbers is : ",a/b)
# Out:
# The division of two numbers is :  11.125
